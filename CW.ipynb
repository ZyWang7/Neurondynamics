# %% [markdown]
# ## Neurodynamics Coursework

# %%
from myModule import myNetwork

# %% [markdown]
# ## P = 0

# %%
num_ex, num_in, num_ex_module, Dmax = 800, 200, 8, 20
myNet = myNetwork(num_ex, num_in, num_ex_module, Dmax)
myNet.set_all()

myNet.plot_connectivity()

# %%
myNet.plot_raster(1000)

# %%
myNet.plot_mean_fire_rate(50, 20, 50)

# %% [markdown]
# ## P = 0.1

# %%
myNet1 = myNetwork(num_ex, num_in, num_ex_module, Dmax)
myNet1.set_all()

myNet1.rewire(0.1)
myNet1.plot_connectivity()

# %%
myNet1.plot_raster(1000)

# %%
myNet1.plot_mean_fire_rate(50, 20, 50)

# %% [markdown]
# ## P = 0.2

# %%
myNet2 = myNetwork(num_ex, num_in, num_ex_module, Dmax)
myNet2.set_all()

myNet2.rewire(0.2)
myNet2.plot_connectivity()

# %%
myNet2.plot_raster(1000)

# %%
myNet2.plot_mean_fire_rate(50, 20, 50)

# %% [markdown]
# ## P = 0.3

# %%
myNet3 = myNetwork(num_ex, num_in, num_ex_module, Dmax)
myNet3.set_all()

myNet3.rewire(0.3)
myNet3.plot_connectivity()

# %%
myNet3.plot_raster(1000)

# %%
myNet3.plot_mean_fire_rate(50, 20, 50)

# %% [markdown]
# ## P = 0.4

# %%
myNet4 = myNetwork(num_ex, num_in, num_ex_module, Dmax)
myNet4.set_all()

myNet4.rewire(0.4)
myNet4.plot_connectivity()

# %%
myNet4.plot_raster(1000)

# %%
myNet4.plot_mean_fire_rate(50, 20, 50)

# %% [markdown]
# ## P = 0.5

# %%
myNet5 = myNetwork(num_ex, num_in, num_ex_module, Dmax)
myNet5.set_all()

myNet5.rewire(0.5)
myNet5.plot_connectivity()

# %%
myNet5.plot_raster(1000)

# %%
myNet5.plot_mean_fire_rate(50, 20, 50)
