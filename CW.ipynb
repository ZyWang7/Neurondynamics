# %%
import numpy as np
import matplotlib.pyplot as plt
import random
from myModule import myNetwork

N = 1000
Dmax = 20
myNet = myNetwork(1000, 20)
myNet.set_all()

myNet.plot_connectivity()

# %%
myNet.plot_raster(1000)

# %%
myNet.plot_mean_fire_rate(50, 20, 50)

# %%
myNet.rewire(0.1)
myNet.get_small_world_index()
myNet.plot_connectivity()

# %%
myNet.plot_raster(1000)

# %%
myNet.plot_mean_fire_rate(50, 20, 50)

# %%
myNet.rewire(0.2)
myNet.get_small_world_index()
myNet.plot_connectivity()

# %%
myNet.plot_raster(1000)

# %%
myNet.plot_mean_fire_rate(50, 20, 50)
